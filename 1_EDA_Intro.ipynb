# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import ast
import seaborn as sns
import matplotlib.pyplot as plt

dataset = load_dataset("lukebarousse/data_jobs")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
df = dataset["train"].to_pandas()
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])
df["job_skills"] = df["job_skills"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_us = df[(df["job_title_short"] == "Data Analyst") & (df["job_country"] == "United States")]

# %%
df_us.head(4)
# Out:
#    job_title_short                                    job_title  \
# 36    Data Analyst                                 Data Analyst
# 68    Data Analyst                    Sr. Research Data Analyst
# 73    Data Analyst  Entry level / Systems Data Analyst (Remote)
# 79    Data Analyst                   Data Analyst/Report Writer
#
#       job_location               job_via job_schedule_type  \
# 36  Des Moines, IA       via Trabajo.org         Full-time
# 68   Baltimore, MD      via ZipRecruiter         Full-time
# 73        Anywhere          via LinkedIn        Contractor
# 79      Austin, TX  via Jobs Trabajo.org         Full-time
#
#     job_work_from_home          search_location     job_posted_date  \
# 36               False  Illinois, United States 2023-11-06 13:01:22
# 68               False  New York, United States 2023-03-24 13:01:00
# 73                True  Illinois, United States 2023-06-16 13:18:22
# 79               False     Texas, United States 2023-08-07 13:18:27
#
# ...

# %%
plot_df = df_us["job_location"].value_counts().head(10).to_frame()

sns.set_theme("paper")
sns.barplot(data=plot_df, x="count", y="job_location", hue="count", palette="dark:b_r", legend=False)
plt.title("Top 10 job locations within the US")
plt.plot()
# Out:
# []

# %%
plot_df = df_us["company_name"].value_counts().head(10).to_frame()

sns.set_theme("paper")
sns.barplot(data=plot_df, x="count", y="company_name", hue="count", palette="dark:b_r", legend=False)
plt.title("Top companies within the US hiring data analysts")
plt.plot()
# Out:
# []
